# %% [markdown]
# # **Project Name** - **Hotel Booking Analysis**

# %% [markdown]
# **Project Type** - EDA
#
# **Contribution** - Individual

# %% [markdown]
# # **Project Summary**
#
# This dataset contains booking information for a ***City Hotel*** and a ***Resort Hotel***, and includes information such as when the booking was made, length of stay, number of adults, children, and/or Babies, and the number of available parking spaces, among other things.All personally identifiable inforamtions have been removed  from the data. The dataset is provided to find out links between different aspects of booking process to help a customer to make a well informed decision for booking at a right time or getting right value. The analysis could also help hotels in improving their services and therefore gaining more user base and even could retain customers in a long run.

# %% [markdown]
# # **GitHub Link : -**
# https://github.com/Mahima1akra/EDA-on-Hotel-booking-analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## Business Problem Overview
#
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
#
# Explore and Analyze the data to discover inportant factors that govern the bookings.

# %% [markdown]
# ## Business Objective
#
# Using Univariate, Bivariate and Multivariate Analysis to find relationship and list out their possible reasons of occurence and provide suggestions for future reference from the Analysis if needed.

# %% [markdown]
# # Importing all the necessary libraries

# %%
# Importing Pandas for data manipulation and aggregation
import pandas as pd

# Importing numpy for efficient computations and usage of arrays
import numpy as np

# Importing Matplotlib and Seaborn for visualizations
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# # Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Importing and Reading Dataset

# %%
# Importing and reading Dataset from GDrive, under the name of df as in 'dataframe'
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Alma Better/Cohort Berlin/Capstone projects/Capstone project 1- EDA on Hotel Booking Analysis/Hotel Bookings.csv")

# %% [markdown]
# ## Data Exploration

# %%
#checking the shape ( rows , columns )
df.shape
# Out:
# (119390, 32)

# %%
# Checking first 5 rows( This includes all the 32 columns )
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Checking last 5 rows
df.tail(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
# looking for the names of all the columns, data types, rows in each columns and non-null entries
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ## **Data Description**
#
# *   *Hotel* :- Type of hotel Booking, i.e. H1 = Resort Hotel, H2 = City Hotel.
# *   *is_cancelled* :- explains if the booking was cancelled(1) or not cancelled(0).
# *   *lead_time* :- Number of days that elapsed between entering date of the booking into the Hotel's management system and the arrival date.
# *   *arrival_date_year* :- year of arrival date.
# *   *arrival_date_month* :- Month of arrival date.
# *   *arrival_date_week_number* :- Week number of year for arrival date.
# *   *arrival_date_day_of_month* :- Day of arrival date.
# *   *stays_in_weekend_nights* :- Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel.
# *   *stays_in_week_nights* :- Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel.
# *   *adults* :- Number of adults.
# *   *children* :- Number of children.
# *   *babies* :- Number of babies.
# *   *meal*:- Type of meal booked. Categories are presented in standard hospitality meal packages.
# *   *country* :- Country of origin.
# *   *market_segment* :- Market segment belongs to. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”.
# *   *distribution_channel* :- Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”.
# *   *is_repeated_guest* :- Value '0' for customers coming for first time and Value '1' for customers who have visited previously.
# *   *previous_cancellations* :- Number of previous bookings that were cancelled by the customer prior to the current booking.
# *   *previous_bookings_not_canceled*:- Number of previous bookings not cancelled by the customer prior to the current booking.
# *   *reserved_room_type* :- Type of room reserved, presented in the form of codes.
# *   *assigned_room_type* :-  Type of room assigned, presented in the form of codes.
# *   *booking_changes* :- count of changes/amendments made from the time of booking till check-in or cancellation.
# *   *deposit_type* :- Suggesting if deposit is made/not made or refunded.
# *   *agent* :- ID of the travel agency that made the booking.
# *   *company* :- ID of the company responsible for booking.
# *   *days_in_waiting_list* :- Number of days the booking was in the waiting list before it was confirmed to the customer.
# *   *customer_type* :- Type of customer.
# *   *adr* :- Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights.
# *   *required_car_parking_spaces* :- Number of car parking spaces required by the customer.
# *   *total_of_special_requests* :- Number of special requests made by the customer(e.g -  type of room or view from the room).
# *   *reservation_status* :- Reservation status, if the booking was cancelled, customer has checked out or customer did not show.
# *   *reservation_status_date*: - Date at which the last status was set.

# %%
# Setting visuals/charts and graphs options

# Set maximum columns to be display in datafram as 36
pd.set_option("display.max_columns", 30)
plt.style.use('seaborn')

# Setting fontsizes,fontweight,label weight for lebels,titles.
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titlesize"] = 25
plt.rcParams["axes.titleweight"] = 'bold'
plt.rcParams['xtick.labelsize']=15
plt.rcParams['ytick.labelsize']=15
plt.rcParams["axes.labelsize"] = 20
plt.rcParams["legend.fontsize"] = 15
plt.rcParams["legend.title_fontsize"] = 15
# Out:
# <ipython-input-8-78c4d72f2cbe>:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# creating a copy of our dataset
df1=df.copy()

# %%
# list of names of all columns
print(list(df1.columns))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %%
# converting object type to datetime
df1['reservation_status_date'] = pd.to_datetime(df1['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# ## **Data Cleaning**

# %%
# checking for the duplicate rows
df1.duplicated().value_counts()
#true means duplicate rows
#Flase means non duplicate
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
# Visulizing through Count pot
# setting up plot and plot size
plt.figure(figsize=(8,6))
sns.countplot(y=df1.duplicated())
# Out:
# <Axes: xlabel='count'>

# %% [markdown]
# From the above graph it can be seen that we have 31994 Duplicate rows in our data, which needs to be removed.

# %%
# Removing the duplicate rows
df1= df1.drop_duplicates()

# %%
# Reduced dataset shape
df1.shape
# Out:
# (87396, 32)

# %%
#checking for Null Values
df1.isna().sum().sort_values(ascending=False)[:5].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#               Columns  Null values
# 0             company        82137
# 1               agent        12193
# 2             country          452
# 3            children            4
# 4  reserved_room_type            0

# %% [markdown]
# We can see from the above that we have null values in company, agent, country and children columns.
#
#
# *   For company and agent column I will replace it with 0 as they have unique values for each one.
# *   For country I will fill it with object 'others'. (with the asssumption that the customer could not find their country and selected others)
# *   Since children column only has 4 missing values I will replace it with zero considering them as there were no children.

# %%
# Filling/replacing null values with 0.
null_columns=['agent','children','company']
for col in null_columns:
  df1[col].fillna(0,inplace=True)


# Replacing NA values with 'others'
df1['country'].fillna('others',inplace=True)

# %%
# Rechecking for  Null Values
df1.isna().sum().sort_values(ascending=False)[:6].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#                        Columns  Null values
# 0                        hotel            0
# 1                  is_canceled            0
# 2           reservation_status            0
# 3    total_of_special_requests            0
# 4  required_car_parking_spaces            0
# 5                          adr            0

# %%
# droppping all 166 those rows in which addtion of adlults ,children and babies is 0. That simply means  no bookings were made.
len(df1[df1['adults']+df1['babies']+df1['children']==0])
df1.drop(df1[df1['adults']+df1['babies']+df1['children']==0].index,inplace=True)

# %%
# Checking the unique values in categorical columns.
categorical_cols=list(set(df1.drop(columns=['reservation_status_date','country','arrival_date_month']).columns)-set(df1.describe()))
for col in categorical_cols:
  print(f'Unique values in {col} column are:, {(df1[col].unique())}')
# Out:
# Unique values in reserved_room_type column are:, ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'B']
# Unique values in distribution_channel column are:, ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# Unique values in deposit_type column are:, ['No Deposit' 'Refundable' 'Non Refund']
# Unique values in assigned_room_type column are:, ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'L' 'K']
# Unique values in market_segment column are:, ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# Unique values in hotel column are:, ['Resort Hotel' 'City Hotel']
# Unique values in customer_type column are:, ['Transient' 'Contract' 'Transient-Party' 'Group']
# Unique values in meal column are:, ['BB' 'FB' 'HB' 'SC' 'Undefined']
# Unique values in reservation_status column are:, ['Check-Out' 'Canceled' 'No-Show']

# %%
# lets add some new columns

df1['total_people'] = df1['adults'] + df1['babies'] + df1['children']
df1['total_stay'] = df1['stays_in_weekend_nights'] + df1['stays_in_week_nights']

# %%
# Checking the final rows and columns
df1.shape
# Out:
# (87230, 34)

# %% [markdown]
# #EDA (Exploratory Data Analysis)

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# #1:- Which type of hotel is mostly prefered by the guests?

# %%
# Visualizing this through a pie chart.
df1['hotel'].value_counts().plot.pie(explode=[0.1, 0.1], autopct='%1.1f%%', shadow = True , figsize=(10,8),fontsize=20)

# setting up plot title
plt.title('Pie Chart for Most Preffered  Hotel')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Most Preffered  Hotel')

# %% [markdown]
# ## **Observation**
# From the chart above it can be seen that City hotel is preferred over Resort Hotel by most customers/guests.
#
# ## **Possible reason**
# There could be several reasons but judging from the ratio of nearly 6:4 it might be possible that the number of City hotels are more compared to Resort hotel. There can be other possible reasons for City hotel being more prefered by guests as compared to Resort hotel which might include Sterotypes, cost incured or any other reason, which cannot be answered at this point of time with current data.

# %% [markdown]
# #2:- Which Agent made the most Hotel bookings?

# %%
# return highest bookings made by agents
highest_bookings= df1.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)

# as agent 0 was NAN value and we replaced it with 0 and indicates no bookings.so droping.
highest_bookings.drop(highest_bookings[highest_bookings['agent']==0].index,inplace=True)

# taking top 10 bookings made by agent
top_ten_highest_bookings=highest_bookings[:10]

top_ten_highest_bookings
# Out:
#      agent  Most_Bookings
# 9      9.0          28721
# 174  240.0          13028
# 14    14.0           3342
# 7      7.0           3294
# 183  250.0           2779
# 175  241.0           1644
# 27    28.0           1493
# 8      8.0           1383
# 1      1.0           1228
# 6      6.0           1117

# %%
#Visualizaing the graph

plt.figure(figsize=(15,8))
sns.barplot(x=top_ten_highest_bookings['agent'],y=top_ten_highest_bookings['Most_Bookings'],order=top_ten_highest_bookings['agent'])

# assigning name for x-axis
plt.xlabel('Agent No')

#assigning name for y-axis
plt.ylabel('Number of Bookings')

# assigning name for the title of the chart
plt.title("Most Bookings Made by the agent")
# Out:
# Text(0.5, 1.0, 'Most Bookings Made by the agent')

# %% [markdown]
# ## **Observation**
# Agent ID-9 made the most number of the bookings

# %% [markdown]
# #3:- What is the pecentage of cancellation of Hotel bookings?

# %%
df1['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(8,8),fontsize=20)
plt.title("Cancellation and non Cancellation")
# Out:
# Text(0.5, 1.0, 'Cancellation and non Cancellation')

# %% [markdown]
# ## **Observation :**
# 0 = not cancelled
#
# 1 = cancelled
#
# More than 72% of the bookings were not cancelled which is good but the higher the better.
#
# ## **Possible reasons**
# Bookings that fell in 27.5% of cancellations can be from various reasons like, last moment change of plans or finding a better or different Hotels, or any technical or any such issue. More research needs to be done to find a definitive answer

# %% [markdown]
# # 4:- What is the Percentage of repeated guests?

# %%
df1['is_repeated_guest'].value_counts().plot.pie(explode=(0.05,0.05),autopct='%1.1f%%',shadow=True,figsize=(8,8),fontsize=15)

plt.title(" Percentgae (%) of repeated guests")
# Out:
# Text(0.5, 1.0, ' Percentgae (%) of repeated guests')

# %% [markdown]
# ## **Observation:**
# Repeated guests are very few which only 3.9 %.
#
# ## **Possible reason**
# Hotels are not able to make a remark in the minds of guests, in order to retained the guests management should take feedbacks from guests and try to imporve the services.

# %% [markdown]
# #5:- What is the percentage distribution of "Customer Type"?

# %%
df1['customer_type'].value_counts().plot.pie(explode=[0.05]*4,autopct='%1.1f%%',figsize=(12,8),fontsize=15,labels=None)


labels=df1['customer_type'].value_counts().index.tolist()
plt.title('% Distribution of Customer Type')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# **1. Transient** : - Walk-in guests, Guests with a last-minute booking, and/or Simply individual guests requiring a short stay at the hotel.
#
# **2. Transient-party** : - when the booking is transient, but is associated to at least other transient booking
#
# **3. Contract** : - when the booking has an allotment or other type of contract associated to it
#
# **4. Group** : - when the booking is associated to a group
#
#
#
#
#
# ## **Observation:**
#  Transient customer type is high which is 82.4 %. percentage of  Booking associated by the Group is vey low.
#
# ## **Possible reason:**
# Guest in the location expect less crowd in the area and more Hotels.

# %% [markdown]
# #6:- What is the percentage distribution of Car parking space required?

# %%
df1['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct='%1.1f%%',shadow=False,figsize=(12,8),fontsize=15,labels=None)

labels=df1['required_car_parking_spaces'].value_counts().index
plt.title('% Distribution of required car parking spaces')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ## **Observation**
# Most guests did not require any parking space. only 8.3 % guests required only one parking space.
#
# ## **Possible reason**
# Guest who require parking space are very low and only need one space, they could either have come from closer locations bringing their own vehichle or a group had brought a bus type of transport, and the third possible reason is rentals. Since parking is not much needed as from the chart, changes made to them would not make much of a change.

# %% [markdown]
# # 7:- What is the percentage of booking changes made by the customer?

# %%
booking_changes_df=df1['booking_changes'].value_counts().reset_index().rename(columns={'index': "number_booking_changes",'booking_changes':'Counts'})

plt.figure(figsize=(12,8))
sns.barplot(x=booking_changes_df['number_booking_changes'],y=booking_changes_df['Counts']*100/df1.shape[0])
plt.title("% of Booking change")
plt.xlabel('Number of booking changes')
plt.ylabel('Percentage(%)')
# Out:
# Text(0, 0.5, 'Percentage(%)')

# %%
booking_changes_percent = booking_changes_df['Counts']*100/df1.shape[0]
booking_changes_percent.head(5).reset_index().rename(columns ={'index' : 'num_of_changes_made' ,'counts' : 'precentage'})
# Out:
#    num_of_changes_made     Counts
# 0                    0  81.881234
# 1                    1  12.459016
# 2                    2   3.992892
# 3                    3   0.988192
# 4                    4   0.397799

# %% [markdown]
# 0= 0 changes made in the booking
#
# 1= 1 changes made in the booking
#
# 2= 2 changes made in the booking
#
# ## **Observation**
# 82% of the guests made no change(denoted by 0) and rest made minor changes.
#
#
# ## **Possible reason**
# Most guests might be satisfied or don't want to make changes considering few number of days they are on.

# %% [markdown]
# # 8: - What is Percentage distribution of Deposite type ?

# %%
df1['deposit_type'].value_counts().plot.pie(explode=(0.5,0.5,0.05),autopct='%1.1f%%',shadow=False,figsize=(14,8),fontsize=20,labels=None)
plt.title("% Distribution of deposit type")
labels=df1['deposit_type'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ## **Observation**
# As much as 98.7 % of the guests prefer "No deposit" type of deposit.
#
# ## **Possible reason**
# Planning on going to a different place can incure unforseen amount which could be spent, along with the quality of service from a Hotel can't be predicted hence the guests might not prefer advance deposits.

# %% [markdown]
# # 9: - Which type of food is mostly preferred by the guests?

# %%
plt.figure(figsize=(14,8))

# Using original dataset directly since not much changes need to be made in this categorical data
sns.countplot(x=df1['meal'])
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Preferred Meal Type")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# Types of meal in hotels:
# * BB - (Bed and Breakfast)
# * HB- (Half Board)
# * FB- (Full Board)
# * SC- (Self Catering)
#
# ## **Observation**
# * It can be seen that the most preferred meal type by the guests is BB( Bed and Breakfast)
# * HB- (Half Board) and SC- (Self Catering) are equally preferred.
#
# ## **Possible reason**
# Guest might want to try local cusines or food from other places. Hotels should ask the opinion of guests in the process of making the food menu and make suitable arrangements as necessary.

# %% [markdown]
# #10: - Which country the most guests are coming from?

# %%
# Counting the guests from different countries and taking first 10
country_df=df1['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:10]


# Visualizing by  plotting the graph
plt.figure(figsize=(15,8))
sns.barplot(x=country_df['country'],y=country_df['count of guests'])
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=12)
plt.title("Number of guests from diffrent Countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %%
#importing the folium library
import folium
import plotly.express as px

# %%
basemap = folium.Map()
guests_map = px.choropleth(country_df, locations = country_df['country'],color = country_df['count of guests'], hover_name = country_df['country'])
guests_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# for accurate number of guests from different countries(top 15 counted here because of count of all the countries)
country_df_all = df1['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:15]
country_df_all
# Out:
#    country  count of guests
# 0      PRT            27355
# 1      GBR            10424
# 2      FRA             8823
# 3      ESP             7244
# 4      DEU             5385
# 5      ITA             3061
# 6      IRL             3015
# 7      BEL             2081
# 8      BRA             1993
# 9      NLD             1910
# 10     USA             1871
# 11     CHE             1566
# 12      CN             1093
# 13     AUT              947
# 14     SWE              833

# %% [markdown]
# ## **Observation**
# ### Most of the guests are coming from portugal i.e more 27000 guests are from portugal
# abbreevations for countries (top 10) : -
# 1.   PRT- Portugal
# 2.   GBR- United Kingdom
# 3.   FRA- France
# 4.   ESP- Spain
# 5.   DEU - Germany
# 6.   ITA -Itlay
# 7.   IRL - Ireland
# 8.   BEL -Belgium
# 9.   BRA -Brazil
# 10.  NLD-Netherlands

# %% [markdown]
# #11: - Which is the most preferred room type by the customers?

# %%
# plotsize
plt.figure(figsize=(15,8))

sns.countplot(x=df1['assigned_room_type'],order=df1['assigned_room_type'].value_counts().index)
plt.xlabel('Room Type')
plt.ylabel('Count of Room Type')
plt.title("Most preferred Room type")
# Out:
# Text(0.5, 1.0, 'Most preferred Room type')

# %% [markdown]
# ## **Observation**
# It can be seen that the room type 'A' is most preferred one, followed by room type 'D' and likewise.

# %% [markdown]
# # 12: - In which month most of the bookings happened?

# %%
# groupby arrival_date_month and taking the hotel count
bookings_by_months_df=df1.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts"})
# Creating the list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# creating df which will map the order of above month's list without changing its values.
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
# sorting by arrival_date_month
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')

bookings_by_months_df
# Out:
#    arrival_date_month  Counts
# 4             January    4685
# 3            February    6083
# 7               March    7489
# 0               April    7900
# 8                 May    8344
# 6                June    7756
# 5                July   10043
# 1              August   11242
# 11          September    6682
# 10            October    6921
# 9            November    4973
# 2            December    5112

# %%
plt.figure(figsize=(20,8))

# pltting lineplot on x= months & y= booking counts
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['Counts'])

# set title for the plot
plt.title('Count of bookings across each month')
plt.xlabel('Month')
plt.ylabel('Number of bookings')
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# ## **Observation**
# The month of August had the most number of bookings and month of July next to it.
#
# ## **Possible reason**
# Since in the month of September there is a sudden decline and also on the month of June, it might be possible that Hotel booking increases due to summer Vaccations.

# %% [markdown]
# #13: - Which Distribution channel is mostly used for hotel bookings?

# %%
#Creating labels
labels=df1['distribution_channel'].value_counts().index.tolist()

# creating new df of distribution channel
distribution_channel_df=df1['distribution_channel'].value_counts().reset_index().rename(columns={'index':"distribution_channel",'distribution_channel':'count'})

#adding percentage columns to the distribution_channel_df
distribution_channel_df['percentage']=round(distribution_channel_df['count']*100/df1.shape[0],1)

#Creating list of percentage
sizes=distribution_channel_df['percentage'].values.tolist()

#plotting the pie chart
df1['distribution_channel'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05,0.05], shadow=False, figsize=(15,8),fontsize=10,labels=None)

# setting legends with the percentage values
labels = [f'{l}, {s}%' for l, s in zip(labels, sizes)]
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
plt.title(' Most used Distribution Channel for Hotel Bookings ')
# Out:
# Text(0.5, 1.0, ' Most used Distribution Channel for Hotel Bookings ')

# %% [markdown]
# ## **Observation**:
# It can be seen that 'TA/TO' is most used for booking hoetls with a dominating 79.1% followed by Direct with a 14.9%.

# %% [markdown]
# # 14: - Which year had the highest bookings?

# %%
plt.figure(figsize=(12,8))

#  plot with countplot
sns.countplot(x=df1['arrival_date_year'],hue=df1['hotel'])
plt.title("Year Wise bookings")
# Out:
# Text(0.5, 1.0, 'Year Wise bookings')

# %% [markdown]
# ## **Observation**
# 2016 had an overall high bookings and 2015 had least bookings.
# overall City hotels had the more bookings compared to Resort hotels.
#
# ## **Possible reasons**
# City hotels are generally cheaper and more in number generally as compared to resort hotels. Guests in resort hotels tend to have a more relaxed vacation as compared to guests in city hotel who generally tend to go on vacation to see locals more and hence want to keep a tight budget and schedule. All of this cannot be definitvely true and further research needs to be done.

# %% [markdown]
# # **Bivariate and Multivariate Analysis**

# %% [markdown]
# #1: - Which type of Hotel has the highest ADR?

# %%
# group by hotel
group_by_hotel=df1.groupby('hotel')

# %%
#grouping by hotel adr
highest_adr=group_by_hotel['adr'].mean().reset_index()

#set plot size
plt.figure(figsize=(10,8))

# set labels
plt.xlabel('Hotel type')
plt.ylabel('ADR')
plt.title("Avg ADR of each Hotel type")

#plot the graph
sns.barplot(x=highest_adr['hotel'],y=highest_adr['adr'])
# Out:
# <Axes: title={'center': 'Avg ADR of each Hotel type'}, xlabel='hotel', ylabel='adr'>

# %% [markdown]
# ## **Observation**
# Average Daily Rate(ADR) : - is the measure of the average paid for rooms sold in a given time period. The metric covers only revenue-generating guestrooms
#
# City hotels has more ADR compared to Resort hotels. This means that city hotels are generating more revenues than the resort hotels.
#
# ## **Possible reason**
# City Hotel having a Higher ADR can mean that they are more efficient in generating revenue as compared to Resort hotels. One of the possible reason can be because of more number and percentage of bookings(as seen from previous data). Other could be the cost of service incurred and other such possible reasons.

# %% [markdown]
# # 2: - Which hotel type has the more lead time?

# %%
# grouping by hotel and taking mean of lead time
avg_lead_time=group_by_hotel['lead_time'].mean().reset_index()

# set plot size
plt.figure(figsize=(10,8))

# plot the bar plot
sns.barplot(x=avg_lead_time['hotel'],y=avg_lead_time['lead_time'])
# set lables
plt.xlabel('Hotel type')
plt.ylabel('Average Lead time')
plt.title("Average Lead Time for each Hotel type")
# Out:
# Text(0.5, 1.0, 'Average Lead Time for each Hotel type')

# %% [markdown]
# ##**Observation**
# Resort hotels has slightly  high avg lead time.
#
# Lead time refers to the time period between booking and cheking in the hotel.
#
# ## **Possible reason**
# Guests booking in resort hotel might be planning in advance compared to city hotel guests.

# %% [markdown]
# #3: - Which hotel has highest percentage of booking cancellation?

# %%
# booking cancelled=1
# booking not cancelled= 0

# creating new DataFrame where bookings are cancelled.
canceled_df=df1[df1['is_canceled']==1]

# Grouping by hotel
canceled_df=canceled_df.groupby('hotel').size().reset_index().rename(columns={0: "no_of_cancelled_bookings"})

# adding total booking column for calculating the percentage.
canceled_df['total_booikngs']=df1.groupby('hotel').size().reset_index().rename(columns={0:"total_bookings"}).drop('hotel',axis=1)
canceled_df

#plotting the barchat
plt.figure(figsize=(10,8))
sns.barplot(x=canceled_df['hotel'],y=canceled_df['no_of_cancelled_bookings']*100/canceled_df['total_booikngs'])

#set labels
plt.xlabel('Hotel type')
plt.ylabel('Percentage(%)')
plt.title("Percentage of booking cancellation")
# Out:
# Text(0.5, 1.0, 'Percentage of booking cancellation')

# %% [markdown]
# ## **Observation**
# City Hotels have a relatively higher percentage of booking cancellations
#
# ## **Possible reason**
# We already saw in data that guests in resort plan in advance so it is possible that the guests have a clear understanding of the hotels they book and hence have a lesser percentage of cancellations.

# %% [markdown]
# #4: - Which type of hotel has longer waiting time?

# %%
# Grouping by hotel and takin mean number of days in waiting list
waiting_time_df=df1.groupby('hotel')['days_in_waiting_list'].mean().reset_index()

#set the plot size
plt.figure(figsize=(10,8))

# plot barchart
sns.barplot(x=waiting_time_df['hotel'],y=waiting_time_df['days_in_waiting_list'])

# set labels
plt.xlabel('Hotel type')
plt.ylabel('waiting time')
plt.title("Waiting time for each hotel type")
# Out:
# Text(0.5, 1.0, 'Waiting time for each hotel type')

# %% [markdown]
# ##**Observation**
# It can be seen that City Hotels has longer waiting period compared to Resort Hotels.
#
# ## **Possible reason**
# City hotel might have a longer waiting time because of the quantity of bookings they have and are hence much busier. Since resort hotels have a longer average lead time it can also be said that city hotels are booked in a moments notice(in an immediate time frame).

# %% [markdown]
# # 5: - Which Hotels has the most repeated guests?

# %%
# repeated guest=1
# non-repeated guest=0
# groupby hotel
repeated_guests_df=df1[df1['is_repeated_guest']==1].groupby('hotel').size().reset_index().rename(columns={0:'number_of_repated_guests'})

# set plot size and plot a barplot
plt.figure(figsize=(10,8))
sns.barplot(x=repeated_guests_df['hotel'],y=repeated_guests_df['number_of_repated_guests'])

# set labels
plt.xlabel('Hotel type')
plt.ylabel('count of repeated guests')
plt.title("Most repeated guests for each hotel")
# Out:
# Text(0.5, 1.0, 'Most repeated guests for each hotel')

# %% [markdown]
# ##**Observation**
# It can be seen that there is not much difference in numbers and they tend to have same number of repeated guests.
#
# ## **Possible reason**
# Although the number of repeated guests who book are same but when we see in previous data of number of city hotel booking to number of resort hotel booking, it can be clearly seen that percentage of repeated guests who book resort is more. This could be because people tend to go to resort hotels for their quality of service and the experience they can have. Hence City hotel needs to improve its services and experience they provide.

# %% [markdown]
# ##6 : -  ADR across the different month.

# %%
# grouping by each month
bookings_by_months_df=df1.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()

#create month list
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# it will take the order of the month list in the df along with values since by default if we do it will go in alphabetical order
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)

#sorting
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')
bookings_by_months_df
# Out:
#    arrival_date_month         hotel         adr
# 8             January    City Hotel   85.269875
# 9             January  Resort Hotel   49.181693
# 6            February    City Hotel   89.266427
# 7            February  Resort Hotel   54.102809
# 15              March  Resort Hotel   57.590889
# 14              March    City Hotel   95.193911
# 0               April    City Hotel  117.314134
# 1               April  Resort Hotel   79.283805
# 17                May  Resort Hotel   80.551101
# 16                May    City Hotel  128.055724
# 13               June  Resort Hotel  112.380859
# 12               June    City Hotel  123.996416
# 11               July  Resort Hotel  156.166914
# 10               July    City Hotel  120.318314
# 3              August  Resort Hotel  187.566659
# 2              August    City Hotel  125.148662
# 22          September    City Hotel  118.764693
# 23          September  Resort Hotel  100.892331
# 20            October    City Hotel  107.585401
# ...

# %%
# set plot size and plot line graph
plt.figure(figsize=(18,8))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['adr'],hue=bookings_by_months_df['hotel'])

# set lables
plt.title('ADR across each month')
plt.xlabel('Month')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ## **Observation**
#
# Both city hotels and resort hotel tend to have a higher bookings in non winter months, with resort hotel bookings starting to increase from the month of May and decreases drastically starting from august, with november and/to January at its lowest point.
#
# Incase of City hotel ADR is not as drastic as resort hotel, but they also tend to be on higher side from march to november.
#
# ## **Possible reason**
#
# Higher ADR(which also means more bookings) in non winter months indicated that the data collected from regions tend to have more pleasant summers or this could be because of summer vacations during this time. Therefore, if bookings are to be made during this time interval then advance bookings are suggested and if the guests want to go during the time when there is lesser number of tourists in the region they should consider going during the months of November to March.

# %% [markdown]
# #7: - Which distribution channel contributed more to ADR in-order to increase the income?

# %%
# grouping by distribution channel and hotel
distribution_channel_df=df1.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()

# set plot size and plot barchart
plt.figure(figsize=(16,8))
sns.barplot(x='distribution_channel', y='adr', data=distribution_channel_df, hue='hotel')
plt.title('ADR across Distribution channel')
# Out:
# Text(0.5, 1.0, 'ADR across Distribution channel')

# %% [markdown]
# * *Corporate* - These are corporate hotel booing companies which makes bookings
# possible.
# * *Direct* - means that bookings are directly made with the respective hotels.
# * *GDS* - A GDS is a worldwide conduit between travel bookers and suppliers, such as hotels and other accommodation providers. It communicates live product, price and availability data to travel agents and online booking engines, and allows for automated transactions.
# * *TA/TO* - means that booings are made through  travel agents or travel operators.
# * *Undefined* - Bookings are undefined. might be because customers made their bookings on arrival.

# %% [markdown]
# ## **Observation**
# It can be seen that 'Direct' and 'TA/TO' have almost equally contributed to ADR in both 'City Hotel' and 'Resort Hotel'. GDS has the most contribution in City Hotel. City hotel on average have a higher ADR.
#
# Looking at GDS it seems that resort hotel is not much explored category in terms of booking which needs to be improved.

# %% [markdown]
# #8: - Which distribution channel has the higest cancellation rate?

# %%
 # 1= canceled for getting dataframe of cancelled bookings
canceled_df=df1[df1['is_canceled']==1]

#grouping by distribution channel
canceled_df=canceled_df.groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'Counts'})

# canceled_df['Percentage']=canceled_df['Counts']*100/df1[df1['is_canceled']==1][0]
canceled_df

#set plot size and plot barchart
plt.figure(figsize=(12,8))
sns.barplot(x='distribution_channel',y='Counts',hue="hotel",data=canceled_df)

# set labels
plt.xlabel('Distribution channel')
plt.ylabel('counts')
plt.title('Cancellation Rate Vs Distribution channel')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Vs Distribution channel')

# %% [markdown]
# ## **Observation**
#
# In "TA/TO"category, the City hotels have a higher cancellation rate compared to resort hotels. In "direct" and "corporate" both the hotels has almost same cancellation rate.
#
# ## **Possible reason**
# Cancellation rates are higher in TA/TO this could mean a lot of things like dissatisfaction with the type of hotel or the guests not getting proper information or a variety of reasons, which is why they need to improve their service and reduce the rate of cancellations.

# %% [markdown]
# #9 : - Which Market Segment  has the higest cancellation rate?

# %%
# DataFrame for looking into market segment specifically
market_segment_df=df1[df1['is_canceled']==1]   # canceled=1
market_segment_df

# Grouping by market segment and hotel
market_segment_df=market_segment_df.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})   # group by

market_segment_df
# Out:
#    market_segment         hotel  counts
# 0        Aviation    City Hotel      45
# 1   Complementary    City Hotel      54
# 2   Complementary  Resort Hotel      31
# 3       Corporate    City Hotel     263
# 4       Corporate  Resort Hotel     246
# 5          Direct    City Hotel     912
# 6          Direct  Resort Hotel     825
# 7          Groups    City Hotel     887
# 8          Groups  Resort Hotel     445
# 9   Offline TA/TO    City Hotel    1257
# 10  Offline TA/TO  Resort Hotel     800
# 11      Online TA    City Hotel   12615
# 12      Online TA  Resort Hotel    5627
# 13      Undefined    City Hotel       2

# %%
#set plotsizde and plot barchart
plt.figure(figsize=(20,8))
sns.barplot(x='market_segment',y='counts',hue="hotel",data= market_segment_df)

# set labels
plt.xlabel('market_segment')
plt.ylabel('Counts')
plt.title('Cancellation Rate Vs market_segment')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Vs market_segment')

# %% [markdown]
# ##**Observation**
# TA/TO has an overall higher cancellations where 'Online T/A' has the highest cancellation in both type of hotels.
# In order to reduce the booking cancellations hotels need to improve their quality of service along with user experience and change their policies.

# %% [markdown]
# #10 : - Are the guests being alloted with the same type of room which they reserve for?

# %%
# Define a function for the reserved room type is same  or not as  assigned room type
def same_room_allotment(x):
  '''function to check whether the reserved room
  type is same or not as assigned room type'''

  if x['reserved_room_type'] != x['assigned_room_type']:
    return 1
  else:
    return 0

# %%
# create new column to df1
df1['Same_room_alloted_or_not']=df1.apply(lambda x: same_room_allotment(x),axis=1)

# grouping by 'is_canceled' column
grp_by_canceled_df=df1.groupby('is_canceled')

# create DF and calculate percentage of same room alloted  or not
DF=pd.DataFrame(grp_by_canceled_df['Same_room_alloted_or_not'].sum()*100/grp_by_canceled_df.size()).rename(columns={0:"percentage"})
DF

#set plot size and plot barchart
plt.figure(figsize=(12,8))
sns.barplot(x=DF.index,y=DF['percentage'])

# set labels
plt.title('%  of not getting the same room vs Booking cancellation')
plt.xlabel('is_canceled')
plt.ylabel('% of not getting same room as per reservation')
plt.xticks([0,1],['Not canceled','canceled'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fa21d8100d0>,
# ...
#  [Text(0, 0, 'Not canceled'), Text(1, 0, 'canceled')])

# %% [markdown]
# ## **Obseravtion**
# It seems that cancellations do not have much effect relative getting a different rooms they are allocated to since booking canceled in this case is as low as 2.5%.
#
# Most guest stick to the room they are allotted to and don't change.

# %% [markdown]
# #11 : - ADR across different  market segments

# %%
# grouping by market segment, hotel type and cancellations
Grupby=df1.groupby(['market_segment','hotel','is_canceled'])['adr'].mean().reset_index()

# set plot size and plto barchart
plt.figure(figsize=(18,6))
sns.barplot(x='market_segment',y='adr',hue='hotel',data=Grupby.sort_values(by='adr',ascending=True))
plt.title('ADR across market segment')
# Out:
# Text(0.5, 1.0, 'ADR across market segment')

# %% [markdown]
# ## **Obseravtion**
# Direct contributes the highest in terms of ADR followed by Online TA.
# Aviation segment should focus on increasing the bookings of Resort Hotel.

# %% [markdown]
# # 12 : - What is the Optimal stay length in both types of hotels ?

# %%
# creating a new dataframe by grouping total stay and hotel
stay = df1.groupby(['total_stay', 'hotel']).agg('count').reset_index()

# considering the 1st 3 columns
stay = stay.iloc[:, :3]

# renaming the columns
stay = stay.rename(columns={'is_canceled':'Number of stays'})

# %%
# set plot size and plot barchart
plt.figure(figsize=(18,9))
sns.barplot(x='total_stay',y='Number of stays',hue='hotel',data=stay)

# set labels
plt.title('Optimal Stay Length in Both hotel types')
plt.ylabel('count of stays')
plt.xlabel('total_stay(days)')
# Out:
# Text(0.5, 0, 'total_stay(days)')

# %% [markdown]
# ## **Observation:**
# Optimal stay in both the types of hotels is less than 6 or 7 days. With City hotel having best at near 3 days and in case of resort hotel till 7 days.

# %% [markdown]
# #13: - Relationship between ADR and total stay.

# %%
# Grouping by adr,total stay and hotel
adr_vs_stay = df1.groupby(['total_stay', 'adr','hotel']).agg('count').reset_index()
adr_vs_stay = adr_vs_stay.iloc[:, :3]
adr_vs_stay = adr_vs_stay.rename(columns={'is_canceled':'Number of stays'})
adr_vs_stay=adr_vs_stay[:18000]
adr_vs_stay
# Out:
#        total_stay     adr         hotel
# 0               0    0.00    City Hotel
# 1               0    0.00  Resort Hotel
# 2               1    0.00    City Hotel
# 3               1    0.00  Resort Hotel
# 4               1    1.00    City Hotel
# ...           ...     ...           ...
# 17995           7  212.06    City Hotel
# 17996           7  212.10  Resort Hotel
# 17997           7  212.14  Resort Hotel
# 17998           7  212.29    City Hotel
# 17999           7  212.29  Resort Hotel
#
# [18000 rows x 3 columns]

# %%
# plot line chart
plt.figure(figsize=(16,8))
sns.lineplot(x='total_stay',y='adr',data=adr_vs_stay)
plt.title('Relationship between adr and total stay')
# Out:
# Text(0.5, 1.0, 'Relationship between adr and total stay')

# %% [markdown]
# ## **Observation**
# ADR increases with number of days staying in hotel.

# %% [markdown]
# # Correlation between different columns

# %%
plt.figure(figsize=(18,10))
sns.heatmap(df1.corr(),annot=True)
plt.title('Co-relation of the columns')
# Out:
# <ipython-input-62-514fd7f81933>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# Text(0.5, 1.0, 'Co-relation of the columns')

# %% [markdown]
# ## **Observation and Inferences**
#
# *   *is_canceled* is negatively correlated with same room alloted as booked, total special requests, number of parking spaces and likewise. This means that they do not affect directly affect the rate of cancellation as we have already done an analysis on some of them.
# *   *lead_time* and *total_stay* seems to be positively correlated and seems reasonable as more the number of days guests stay in a hotel the bookings will be delayed for those hotels.
# *   *Adults* and *children* are positively correlated to *ADR* which directly means that more the number of guests more is the ADR generated.
# *   *is_repeated_guest* correlates to *previous_bookings_not canceled*, which means that is the guests who are more satisfied with the current stay and if it leaves a positive remark on them, then they are likely to come back and not cancel bookings.

# %% [markdown]
# #14 : - Is there relationship between repeated guests and previous bookings not canceled?

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=df1['is_repeated_guest'],y= df1['previous_bookings_not_canceled'])
plt.xticks([0,1],['Non_repeated_guests','repeated_guests'],fontsize=15)
plt.title('Relationship Between repeated guests and previous bookings not cancelled.')
plt.show()

# %% [markdown]
# ## **Observation**
# Repeated guests seem to have less *previous_bookings_not_canceled* which means that guests who are repeated have less bookings canceled previously.
#
# This could mean more the happy customer more is the chance they might be back.

# %%
# to maintain consistencies
df1.drop(df1[df1['adr'] > 5000].index, inplace = True)

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(x=df1['total_stay'],y=df1['adr'])
plt.title('Relationship between  adr and total stay')
# Out:
# Text(0.5, 1.0, 'Relationship between  adr and total stay')

# %% [markdown]
# ## **Observation**
# With increase in *total_stay*, *adr* is decreasing which means that if guests intend to stay longer it will be good for them, but at the same time it will be bad for the hotel in generating adr.

# %% [markdown]
# # ADR relationship with total number of people

# %%
plt.figure(figsize=(15,8))
df2=df1[df1['total_people'] < 6]

sns.boxplot(x=df2['total_people'],y=df2['adr'])

# set lables
plt.title('ADR v/s Total Number of people')
# Out:
# Text(0.5, 1.0, 'ADR v/s Total Number of people')

# %% [markdown]
# ## **Observation**
# With increase in number of people, adr also increases.
#
# ## **Possible reason**
# more people require more space and beddings which increases price and hence more adr is generated with more number of people. If the guests do eat or use any of hotel facilities it also adds up to their revenue.

# %% [markdown]
# ## **Suggestions**
#
#
# *   AN optimal stay of 3 to 4 days in City Hotel is an optimal stay for most guests and can extend up to 7 days.
# *   More number of guests are better for both hotels and guests in group, as it will bring down individual price for the room for guests and will generate more ADR for Hotels.
# *   Waiting time for City hotel is more and lead time is less so guests can book on-spot during less crowded seasons and resort hotels have a longer lead time hence they are adviced to book in advance.
# *   Non-winter seasons(April till October) have a higher traffic of guests in the region hence the guests are advised to book in advance during these seasons if they want to visit or if they want to visit during less crowded time they should consider during winter season.
# *   Hotel's staff are advised to learn international languages which would make it easier for them to communicate since most of the guests are from different countries. They should consider learning Portuguese, English, French and Espanol since guests from these contries are higher in number.
# *   City hotels are more preferred by guests and Resort hotels are preferred for longer stays.

# %% [markdown]
# # **Conclusions : -**
# A quick summary of all the analysis made :
# *   City hotels might be prefered by a higher number of guests as compared to Resort hotels by looking through the number of bookings.
# *   Most guests do not cancel their bookings but some do(in our case roughly 27.5%)
# *   Most guests do not book the same hotel more than once, hence retention rates are quite low(Only 3.9% of them were repeated). This could be for a variety of reason which can be further explored later.
# *   Transient type of guests are the highest percentage among different type of guests which is more than 82%.
# *   More than 90% of guests do not require parking spaces and nearly 8% of them require parking space for one vehicle.
# *   Nearly 82% of guests made no special requests and 12% and 3.9% of guests made change requests for two and three changes respectively.
# *   'No deposit' was the most prefered type of deposition type by guests with over 98%.
# *   Bed and Breakfast(BB) was the most prefered type of meal followed by Half Board(HB) and Self Catering(SC). Customers might want to have peace and slow start with breakfast at their hotel and similar for the end of day with no stress of choosing where to eat or at what time since it is nearer to their hotel rooms.
# *   Top three countries most number guests were from Portugal with over 27000 guests followed by Great Britain and France.
# *   Travel Agent and Travel Operator is the most prefered type of Distribution channel for hotel booking at 79% and Direct is second to that with nearly 15%.
# *   2016 had an overall high bookings and City hotel being a dominant one in most years except for the year 2015 where they were nearly equal.
# *   City hotel generated relatively higher ADR and Resort hotels had a relatively longer lead time which could explain the frequency and traffic of guests in both type of hotels.(City hotel has more)
# *   City hotel has a higher cancellation and waiting time compared to resort hotels.
# *   City hotel and Resort hotels have similar figures when it comes to customer retentions(as seen from repeated customers secction) but when they are compared to number of guests visiting in hotels, resort hotels are performing better.
# *   Hotels are generating more ADR during non winter months(march till october) and there is a sudden spike in the month of August in the case of resort hotel. SO if guests want to go during these months they must book in advance.
# *   TA/TO had higher cancellation rate when it came to distribution channels where online TA has the highest and Direct and Corporate has a ballanced cancellation rates for both types of hotel.
# *   Cancelation of booking show no relation with different rooms being assigned as compared to bookings made because most customers still took the room which they were given and did not cancel the booking
# *   TA/TO contributed highest ADR with Online TA and Direct channels contiributed highest ADR amongst other modes of channel.
# *   Optimal stay in both hotels is 6 to 7 days at max with 3 days for city hotel suits the best for most customers.
# *   ADR increased with total stay and more number of people.
# *   Previous booking not canceled had a positive correlation with repeated guests.
